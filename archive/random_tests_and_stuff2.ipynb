# %%
from utils import check_dataset, load_files_from_json, find_task, create_basic_prompt, generate_coding_prompt, generate_prompt_with_image, generate_code_fixing_prompt, generate_continued_code_fixing_prompt
from llm_utils import generate_llm_response, initialize_client
from eval import extract_solution, evaluate_solution, fix_output_string, extract_code, execute_transform_function

import time
import json

import ast

import numpy as np
import pandas as pd

# %%
check_dataset()
train, eval = load_files_from_json()

config = {
    #'model': 'meta-llama/Llama-Vision-Free',
    #'model': 'pixtral-large-latest',
    # 'model': 'qwen/qwen2.5-vl-72b-instruct:free',
    #'model': 'google/gemma-3-27b-it:free',
    'model': 'codestral-latest',
    'solution_type': 'program_synthesis',
    #'temperatures': [0.1, 0.3, 0.5, 0.7, 0.9],
    'temperatures': [0.1, 0.3],
    'samples_per_step': 5,
    'code_correction_steps': 3
}

client = initialize_client('mistral')
print("Client initialized!")

#TODO: fix this
#file_path_initial_sampling = f"results/program_synthesis/{config['model']}_sampling.csv"
#file_path_code_fixing = f"results/program_synthesis/{config['model']}_code_fixing.csv"

# Load initial sampling results and create a subset of tasks where fixing the code might be successful
df = pd.read_csv("results/program_synthesis/codestral_full.csv")

solved_tasks = set(df.query("average_percentage_correct == 1.0")['task'].to_list())
relevant_tasks = set(df.query("average_percentage_correct > 0.8 and average_percentage_correct != 1 and task not in @solved_tasks")["task"].to_list())

attempt_fixing = (
    df
    .query("""task in @relevant_tasks and \
            average_percentage_correct != 1 and \
            (average_percentage_correct > 0.8 or \
            count_perfect_scores > 1)""")
    .drop_duplicates(subset=["average_percentage_correct"], keep='first')
    .sort_values(["count_perfect_scores", "average_percentage_correct"], ascending=False)
    .groupby("task")
    .head(3)
)

#Variables for final results

df_code_fix = pd.DataFrame()
df_info = pd.DataFrame()

#Run the code fixing for every entry in the dataframe that seems promising, max 3 per task
for index, (_, row) in enumerate(attempt_fixing.iterrows()):
    
    
    
    additional_infos = []
    task_id = row['task']
    task = train[task_id]
    answer = row['full_answer']
    generated_grids = ast.literal_eval(row['generated_grids'])

    messages = (generate_code_fixing_prompt(task=task, 
                                            extracted_answer=answer, 
                                            generated_inputs=generated_grids))
    
    for attempt_counter in range(0, config['code_correction_steps']):
        
        responses_list = []
        code_results = []
        additional_info = []

        
        print(f"Attempting to fix code for {row['task']}.")
        print(f"#{index} out of {attempt_fixing.shape[0]} -- Attempt #{attempt_counter+1} out of {config['code_correction_steps']}.")
        print("Generating code...")

        for temp in config['temperatures']:
            print(f"Generating {config['samples_per_step']} solutions using temperature {temp}")
            responses, additional_info = generate_llm_response(messages, 
                                                               client=client, 
                                                               model=config['model'],
                                                               num_samples=config['samples_per_step'], 
                                                               temperature=temp)
            #Ensure we dont exceed rate limits on API-services
            time.sleep(1.5)
            # Save the responses text to extract code and test its performance
            responses_list.extend(responses)
            # Save additional info for later data analysis
            additional_info.insert(0, task_id)
            additional_info.append(temp)
            additional_infos.append(additional_info)

        # From each response in the list, extract the python code and save to another list   
        generated_programs = []    
        for response in responses_list:
            extracted_code = extract_code(response)
            generated_programs.append(extracted_code)
        print(f"Saved {len(generated_programs)} from output.")
        

        for i, generated_code in enumerate(generated_programs):
            print(f"Attempting to run program #{i}...")
        
            generated_output_grids = []
            dicts_list = []
            # Set up individual input/output examples as arrays
            for example in task['train']:
                example_input = example['input']
                example_output = np.array(example['output'])
                # Then execute generated code for each example
                output_grid_with_llm_code = execute_transform_function(generated_code, example_input)
                generated_output_grids.append(output_grid_with_llm_code)
                try:
                    solution_array = np.array(output_grid_with_llm_code)
                except:
                    print("No numpy array could be made :(")
                # compare generated output to actual output
                result = evaluate_solution(solution_array, example_output)
                dicts_list.append(result)

            for d in dicts_list:
                print(d)
        
            # calculate performance indicators for each code generation
            percentage_correct_values = [d['percentage_correct'] for d in dicts_list]
            average_percentage_correct = sum(percentage_correct_values) / len(percentage_correct_values)
            count_perfect_scores = sum(1 for d in dicts_list if d['percentage_correct'] == 1.0)
            print(i, average_percentage_correct, count_perfect_scores)

            # save results:            
            row = (
            {
                'task': task_id,
                'sample_num': i+1,
                'full_answer': responses_list[i],
                'extracted_code': generated_code,
                'generated_grids': generated_output_grids,
                'average_percentage_correct': average_percentage_correct,
                'count_perfect_scores': count_perfect_scores,
                'num_attempt': attempt_counter
            })
            code_results.append(row)

        partial_df = pd.DataFrame(code_results)
        df_code_fix = pd.concat([df_code_fix, partial_df], ignore_index=True)
        
        # Check if solution was found:
        #df_temp = pd.DataFrame(code_results)
        if (not partial_df.query("average_percentage_correct == 1").empty):
            print(f"Solution found after {attempt_counter} attempts!")
            break
        
        # Else determine best generated solution and start new code fixing attempt
        else:
            sorted_df = partial_df.sort_values(["count_perfect_scores", "average_percentage_correct"], ascending=False).head(1)
            result_dict = sorted_df.to_dict(orient='records')[0]
            
            # Generate new code fixing prompt
            updated_user_prompt = generate_continued_code_fixing_prompt(result_dict['generated_grids'])
            
            # Update "conversation" with LLM
            messages.append({"role": "assistant", "content": result_dict['full_answer']})
            messages.append({"role": "user", "content": updated_user_prompt})
            
            print("Starting new attempt...")
            attempt_counter += 1
    
    # Save results after every loop in case something breaks        
    df_code_fix.to_csv("results/program_synthesis/codestral_code_fixing_test2.csv", index=False)
    df_info.to_csv("results/program_synthesis/codestral_code_fixing_test_info2.csv", index=False)
# Out:
# ARC data complete.
# Client initialized!
# Attempting to fix code for aedd82e4.
# #0 out of 128 -- Attempt #1 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 2.39 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 3.49 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 0 1.0 4
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.88}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.95}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 1 0.875 0
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 2 1.0 4
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 3 1.0 4
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 4 1.0 4
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 5 1.0 4
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 6 1.0 4
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.88}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.95}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 7 0.875 0
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.88}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.95}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 8 0.875 0
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 9 1.0 4
# Solution found after 0 attempts!
# Attempting to fix code for 9565186b.
# #1 out of 128 -- Attempt #1 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 1.44 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 2.06 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 0 0.8325 3
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 1 0.8325 3
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 2 0.8325 3
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 3 0.8325 3
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 4 0.8325 3
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.56}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 5 0.8625 2
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 6 0.8325 3
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 7 0.8325 3
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.56}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 8 0.8625 2
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 9 0.8625 1
# Starting new attempt...
# Attempting to fix code for 9565186b.
# #1 out of 128 -- Attempt #2 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 40.69 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 34.08 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 0 0.8325 3
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 1 0.8325 3
# Attempting to run program #2...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 2 0.0 0
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 3 0.8325 3
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 4 0.8325 3
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 5 0.8325 3
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 6 0.8325 3
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 7 0.8325 3
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 8 0.8325 3
# Attempting to run program #9...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 9 0.0 0
# Starting new attempt...
# Attempting to fix code for 9565186b.
# #1 out of 128 -- Attempt #3 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 33.70 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 33.97 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.67}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.22}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# 0 0.5 0
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 1 0.8325 3
# Attempting to run program #2...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 2 0.0 0
# Attempting to run program #3...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 3 0.0 0
# Attempting to run program #4...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 4 0.0 0
# Attempting to run program #5...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 5 0.0 0
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 6 0.8325 3
# Attempting to run program #7...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 7 0.0 0
# Attempting to run program #8...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 8 0.0 0
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.33}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 9 0.8325 3
# Starting new attempt...
# Attempting to fix code for 44f52bb0.
# #2 out of 128 -- Attempt #1 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 3.63 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 10.95 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 0 0.5 3
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 1 0.5 3
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 2 0.5 3
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 3 0.5 3
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 4 0.5 3
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 5 0.5 3
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 6 0.5 3
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 7 0.8333333333333334 5
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 8 0.5 3
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 9 0.5 3
# Starting new attempt...
# Attempting to fix code for 44f52bb0.
# #2 out of 128 -- Attempt #2 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 4.24 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 4.66 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 0 0.8333333333333334 5
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 1 0.8333333333333334 5
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 2 0.8333333333333334 5
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 3 0.8333333333333334 5
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 4 0.5 3
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 5 0.5 3
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 6 0.5 3
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 7 0.5 3
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 8 0.5 3
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 9 0.8333333333333334 5
# Starting new attempt...
# Attempting to fix code for 44f52bb0.
# #2 out of 128 -- Attempt #3 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 34.63 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 34.49 seconds
# Saved 10 from output.
# Attempting to run program #0...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 0 0.0 0
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 1 0.16666666666666666 1
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 2 0.8333333333333334 5
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 3 0.16666666666666666 1
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 4 0.8333333333333334 5
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 5 0.6666666666666666 4
# Attempting to run program #6...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 6 0.0 0
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 7 0.6666666666666666 4
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# 8 0.5 3
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 9 0.8333333333333334 5
# Starting new attempt...
# Attempting to fix code for f8a8fe49.
# #3 out of 128 -- Attempt #1 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 4.06 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 4.45 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 0 0.9933333333333333 2
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 1 0.9933333333333333 2
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 2 0.9933333333333333 2
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 3 0.9933333333333333 2
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 4 0.9933333333333333 2
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 5 0.9933333333333333 2
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 6 0.9933333333333333 2
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 7 0.9933333333333333 2
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 8 0.9933333333333333 2
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 9 0.9933333333333333 2
# Starting new attempt...
# Attempting to fix code for f8a8fe49.
# #3 out of 128 -- Attempt #2 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 5.90 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 6.26 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 0 0.9933333333333333 2
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 1 0.9966666666666667 2
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 2 0.9966666666666667 2
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 3 0.9966666666666667 2
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 4 0.9933333333333333 2
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 5 0.9933333333333333 2
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 6 0.9966666666666667 2
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 7 0.9966666666666667 2
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.98}
# 8 0.9933333333333333 2
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 9 0.9966666666666667 2
# Starting new attempt...
# Attempting to fix code for f8a8fe49.
# #3 out of 128 -- Attempt #3 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 20.97 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 18.01 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 0 0.9966666666666667 2
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 1 0.9966666666666667 2
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 2 0.9966666666666667 2
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 3 0.9966666666666667 2
# Attempting to run program #4...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 4 0.0 0
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 5 0.9966666666666667 2
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 6 0.9966666666666667 2
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 7 0.9966666666666667 2
# Attempting to run program #8...
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# Error executing code: exec() arg 1 must be a string, bytes or code object
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# {'answer_extracted': True, 'correct_grid_size': False, 'percentage_correct': 0.0}
# 8 0.0 0
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.99}
# 9 0.9966666666666667 2
# Starting new attempt...
# Attempting to fix code for b0c4d837.
# #4 out of 128 -- Attempt #1 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 2.77 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 3.01 seconds
# Saved 10 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# 0 0.9083333333333333 2
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# 1 0.9083333333333333 2
# Attempting to run program #2...
# ...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 1 0.8814285714285715 0
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.92}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 2 0.8814285714285715 0
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.73}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.56}
# 3 0.8885714285714285 3
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.92}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 4 0.8814285714285715 0
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.92}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 5 0.8814285714285715 0
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.92}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 6 0.8814285714285715 0
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.92}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 7 0.8814285714285715 0
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.84}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 8 0.87 0
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.8}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.92}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.96}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.97}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 9 0.8814285714285715 0
# Starting new attempt...
# Attempting to fix code for dc433765.
# #5 out of 128 -- Attempt #2 out of 3.
# Generating code...
# Generating 5 solutions using temperature 0.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 75
#      73 for temp in config['temperatures']:
#      74     print(f"Generating {config['samples_per_step']} solutions using temperature {temp}")
# ---> 75     responses, additional_info = generate_llm_response(messages,
#      76                                                        client=client,
#      77                                                        model=config['model'],
#      78                                                        num_samples=config['samples_per_step'],
#      79                                                        temperature=temp)
#      80     #Ensure we dont exceed rate limits on API-services
#      81     time.sleep(1.5)
#
# File ~/Projects/masters_thesis/llm_utils.py:55, in generate_llm_response(messages, client, model, base64_image, extra_body, num_samples, temperature, top_p)
#      50 start_time = time.time()
#      52 try:
#      53     #completion = client.chat.completions.create(
#      54     # mistral:
# ---> 55     completion = client.chat.complete(
#      56
#      57         model=model,
#      58         messages=messages,
#      59         temperature=temperature,
#      60         top_p=top_p,
#      61         max_tokens=6000,
#      62         n=num_samples
#      63     )
#      65     end_time = time.time()  # End timing
#      66     processing_time = end_time - start_time
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/mistralai/chat.py:214, in Chat.complete(self, model, messages, temperature, top_p, max_tokens, stream, stop, random_seed, response_format, tools, tool_choice, presence_penalty, frequency_penalty, n, prediction, safe_prompt, retries, server_url, timeout_ms, http_headers)
#     211 if isinstance(retries, utils.RetryConfig):
#     212     retry_config = (retries, ["429", "500", "502", "503", "504"])
# --> 214 http_res = self.do_request(
#     215     hook_ctx=HookContext(
#     216         operation_id="chat_completion_v1_chat_completions_post",
#     217         oauth2_scopes=[],
#     218         security_source=get_security_from_env(
#     219             self.sdk_configuration.security, models.Security
#     220         ),
#     221     ),
#     222     request=req,
#     223     error_status_codes=["422", "4XX", "5XX"],
#     224     retry_config=retry_config,
#     225 )
#     227 data: Any = None
#     228 if utils.match_response(http_res, "200", "application/json"):
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/mistralai/basesdk.py:273, in BaseSDK.do_request(self, hook_ctx, request, error_status_codes, stream, retry_config)
#     271     http_res = utils.retry(do, utils.Retries(retry_config[0], retry_config[1]))
#     272 else:
# --> 273     http_res = do()
#     275 if not utils.match_status_codes(error_status_codes, http_res.status_code):
#     276     http_res = self.sdk_configuration.get_hooks().after_success(
#     277         AfterSuccessContext(hook_ctx), http_res
#     278     )
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/mistralai/basesdk.py:234, in BaseSDK.do_request.<locals>.do()
#     224     req = self.sdk_configuration.get_hooks().before_request(
#     225         BeforeRequestContext(hook_ctx), request
#     226     )
#     227     logger.debug(
#     228         "Request:\nMethod: %s\nURL: %s\nHeaders: %s\nBody: %s",
#     229         req.method,
#    (...)
#     232         get_body_content(req),
#     233     )
# --> 234     http_res = client.send(req, stream=stream)
#     235 except Exception as e:
#     236     _, e = self.sdk_configuration.get_hooks().after_error(
#     237         AfterErrorContext(hook_ctx), None, e
#     238     )
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Projects/masters_thesis/venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.12/ssl.py:1232, in SSLSocket.recv(self, buflen, flags)
#    1228     if flags != 0:
#    1229         raise ValueError(
#    1230             "non-zero flags not allowed in calls to recv() on %s" %
#    1231             self.__class__)
# -> 1232     return self.read(buflen)
#    1233 else:
#    1234     return super().recv(buflen, flags)
#
# File /usr/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103         return self._sslobj.read(len, buffer)
#    1104     else:
# -> 1105         return self._sslobj.read(len)
#    1106 except SSLError as x:
#    1107     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
solved_tasks = set(df.query("average_percentage_correct == 1.0")['task'].to_list())
relevant_tasks = set(df.query("average_percentage_correct > 0.8 and average_percentage_correct != 1 and task not in @solved_tasks")["task"].to_list())

len(relevant_tasks)
# Out:
# 197

# %%
attempt_fixing = (
    df
    .query("""task in @relevant_tasks and \
            average_percentage_correct != 1 and \
            (average_percentage_correct > 0.8 or \
            count_perfect_scores > 1)""")
    .drop_duplicates(subset=["average_percentage_correct"], keep='first')
    .sort_values(["count_perfect_scores", "average_percentage_correct"], ascending=False)
    .groupby("task")
    .head(3)
)

attempt_fixing.shape
# Out:
# (128, 7)

# %%
additional_infos = []
code_results = []

for index, row in attempt_fixing.iterrows():
    
    print(f"Attempting to fix code for {row['task']}.")
    print(f"#{index} out of {attempt_fixing.shape[0]}")
    
    print("Generating code...")
    responses_list = []
    additional_info = []

    task_id = row['task']
    task = train[task_id]
    answer = row['full_answer']
    generated_grids = ast.literal_eval(row['generated_grids'])
    
    messages = (generate_code_fixing_prompt(task=task, 
                                          extracted_answer=answer, 
                                          generated_inputs=generated_grids))
    
    for temp in config['temperatures']:
        print(f"Generating {config['samples_per_step']} solutions using temperature {temp}")
        responses, additional_info = generate_llm_response(messages, 
                                                           client=client, 
                                                           model=config['model'],
                                                           num_samples=config['samples_per_step'], 
                                                           temperature=temp)
        
        # Save the responses text to extract code and test its performance
        responses_list.extend(responses)
        
        # Save additional info for later data analysis
        additional_info.insert(0, task_id)
        additional_info.append(temp)
        additional_infos.append(additional_info)
        
    # From each response in the list, extract the python code and save to another list   
    generated_programs = []    
    for response in responses_list:
        extracted_code = extract_code(response)
        generated_programs.append(extracted_code)
        
    print(f"Saved {len(generated_programs)} from output.")
    
    generated_output_grids = []
        
    for i, generated_code in enumerate(generated_programs):
    
        print(f"Attempting to run program #{i}...")
        generated_output_grids = []
        dicts_list = []
        # Set up individual input/output examples as arrays
        for example in task['train']:
            example_input = example['input']
            example_output = np.array(example['output'])
            
            # Then execute generated code for each example
            output_grid_with_llm_code = execute_transform_function(generated_code, example_input)
            generated_output_grids.append(output_grid_with_llm_code)
            
            try:
                solution_array = np.array(output_grid_with_llm_code)
            except:
                print("No numpy array could be made :(")
            # compare generated output to actual output
            result = evaluate_solution(solution_array, example_output)
            dicts_list.append(result)
    
        for d in dicts_list:
            print(d)
        
        # calculate performance indicators for each code generation
        percentage_correct_values = [d['percentage_correct'] for d in dicts_list]
        average_percentage_correct = sum(percentage_correct_values) / len(percentage_correct_values)
        count_perfect_scores = sum(1 for d in dicts_list if d['percentage_correct'] == 1.0)
        
        print(i, average_percentage_correct, count_perfect_scores)
        # save results:            
        row = (
        {
            'task': task_id,
            'sample_num': i+1,
            'full_answer': responses_list[i],
            'extracted_code': generated_code,
            'generated_grids': generated_output_grids,
            'average_percentage_correct': average_percentage_correct,
            'count_perfect_scores': count_perfect_scores
        })
        
        code_results.append(row)
    
    # Save results after every loop in case something breaks    
    df_code_fix = pd.DataFrame(code_results)
    df_code_fix.to_csv("results/program_synthesis/codestral_code_fixing_test.csv", index=False)

    df_info = pd.DataFrame(additional_infos,
                       columns=['task_name', 'processing_time', 'samples_drawn', 'input_tokens', 'output_tokens', 'temperature'])
    df_info.to_csv("results/program_synthesis/codestral_code_fixing_test_info.csv", index=False)
    
    time.sleep(1.5)
# Out:
# Attempting to fix code for aedd82e4.
# #11654 out of 128
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 2.38 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 2.78 seconds
# Generating 5 solutions using temperature 0.5
# Time taken for 5 sample(s): 2.26 seconds
# Generating 5 solutions using temperature 0.7
# Time taken for 5 sample(s): 2.80 seconds
# Generating 5 solutions using temperature 0.9
# Time taken for 5 sample(s): 2.70 seconds
# Saved 25 from output.
# Attempting to run program #0...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.88}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.95}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 0 0.875 0
# Attempting to run program #1...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.88}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.95}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 1 0.875 0
# Attempting to run program #2...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 2 1.0 4
# Attempting to run program #3...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 3 1.0 4
# Attempting to run program #4...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 4 1.0 4
# Attempting to run program #5...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 5 1.0 4
# Attempting to run program #6...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 6 1.0 4
# Attempting to run program #7...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 7 1.0 4
# Attempting to run program #8...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 8 1.0 4
# Attempting to run program #9...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 9 1.0 4
# Attempting to run program #10...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 10 1.0 4
# Attempting to run program #11...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 11 1.0 4
# Attempting to run program #12...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 12 1.0 4
# Attempting to run program #13...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 13 1.0 4
# Attempting to run program #14...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 14 1.0 4
# Attempting to run program #15...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 15 1.0 4
# Attempting to run program #16...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 16 1.0 4
# Attempting to run program #17...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 17 1.0 4
# Attempting to run program #18...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 18 1.0 4
# Attempting to run program #19...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 19 1.0 4
# Attempting to run program #20...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 20 1.0 4
# Attempting to run program #21...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.89}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.88}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.95}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 0.78}
# 21 0.875 0
# Attempting to run program #22...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 22 1.0 4
# Attempting to run program #23...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 23 1.0 4
# Attempting to run program #24...
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# {'answer_extracted': True, 'correct_grid_size': True, 'percentage_correct': 1.0}
# 24 1.0 4
# Attempting to fix code for 9565186b.
# #19600 out of 128
# Generating code...
# Generating 5 solutions using temperature 0.1
# Time taken for 5 sample(s): 1.57 seconds
# Generating 5 solutions using temperature 0.3
# Time taken for 5 sample(s): 2.19 seconds
# Generating 5 solutions using temperature 0.5
# Time taken for 5 sample(s): 1.19 seconds
# Generating 5 solutions using temperature 0.7
# Time taken for 5 sample(s): 1.73 seconds
# Generating 5 solutions using temperature 0.9
# Error calling LLM: API error occurred: Status 429
# {"message":"Requests rate limit exceeded"}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 26
#      24 for temp in config['temperatures']:
#      25     print(f"Generating {config['samples_per_step']} solutions using temperature {temp}")
# ---> 26     responses, additional_info = generate_llm_response(messages,
#      27                                                        client=client,
#      28                                                        model=config['model'],
#      29                                                        num_samples=config['samples_per_step'],
#      30                                                        temperature=temp)
#      32     # Save the responses text to extract code and test its performance
#      33     responses_list.extend(responses)
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
df_llama11b = pd.read_csv("results/llama-11b-vl_oneshot_reason.csv")
df_llama11b.query("percentage_correct == 1").count()
# Out:
# task                    13
# llm_full_answer         13
# llm_extracted_answer    13
# answer_extracted        13
# correct_grid_size       13
# percentage_correct      13
# dtype: int64

# %%
df_code_fix.query("average_percentage_correct == 1")
# Out:
#         task  sample_num                                        full_answer  \
# 0   aedd82e4           1  The reasoning provided by your colleague is co...
# 1   aedd82e4           2  The initial reasoning is correct, but the impl...
# 2   aedd82e4           3  The initial reasoning is correct, but the impl...
# 3   aedd82e4           4  The initial reasoning is correct, but the impl...
# 4   aedd82e4           5  The initial reasoning is correct, but the impl...
# 5   aedd82e4           6  The initial reasoning is correct, but the impl...
# 7   aedd82e4           8  The initial reasoning is correct, but the impl...
# 8   aedd82e4           9  The initial reasoning is correct, but the impl...
# 9   aedd82e4          10  The initial reasoning is correct, but the impl...
# 10  aedd82e4          11  The problem lies in the implementation of the ...
# 11  aedd82e4          12  The reasoning provided by your colleague is co...
# 12  aedd82e4          13  The reasoning provided by your colleague is co...
# 13  aedd82e4          14  The issue lies in the implementation of the `i...
# 14  aedd82e4          15  The initial reasoning and implementation are m...
# 15  aedd82e4          16  The reasoning provided by your colleague is co...
# 16  aedd82e4          17  The reasoning provided by your colleague is co...
# 17  aedd82e4          18  The initial reasoning is correct, but the impl...
# 18  aedd82e4          19  The reasoning provided by your colleague is co...
# 19  aedd82e4          20  The initial reasoning and implementation are m...
# 21  aedd82e4          22  The initial reasoning is correct, but the impl...
# 22  aedd82e4          23  The initial reasoning was correct, but the imp...
# 24  aedd82e4          25  The initial reasoning is correct, but the impl...
#
#                                        extracted_code  \
# 0   def transform_grid(grid):\n    rows = len(grid...
# 1   def transform_grid(grid):\n    rows = len(grid...
# 2   def transform_grid(grid):\n    rows = len(grid...
# 3   def transform_grid(grid):\n    rows = len(grid...
# 4   def transform_grid(grid):\n    rows = len(grid...
# 5   def transform_grid(grid):\n    rows = len(grid...
# 7   def transform_grid(grid):\n    rows = len(grid...
# 8   def transform_grid(grid):\n    rows = len(grid...
# 9   def transform_grid(grid):\n    rows = len(grid...
# 10  def transform_grid(grid):\n    rows = len(grid...
# 11  def transform_grid(grid):\n    rows = len(grid...
# 12  def transform_grid(grid):\n    rows = len(grid...
# 13  def transform_grid(grid):\n    rows = len(grid...
# 14  def transform_grid(grid):\n    rows = len(grid...
# 15  def transform_grid(grid):\n    rows = len(grid...
# 16  def transform_grid(grid):\n    rows = len(grid...
# 17  def transform_grid(grid):\n    rows = len(grid...
# 18  def transform_grid(grid):\n    rows = len(grid...
# 19  def transform_grid(grid):\n    rows = len(grid...
# 21  def transform_grid(grid):\n    rows = len(grid...
# 22  def transform_grid(grid):\n    rows = len(grid...
# 24  def transform_grid(grid):\n    rows = len(grid...
#
#                                       generated_grids  \
# 0   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 1   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 2   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 3   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 4   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 5   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 7   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 8   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 9   [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 10  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 11  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 12  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 13  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 14  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 15  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 16  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 17  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 18  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 19  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 21  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 22  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
# 24  [[[0, 2, 2], [0, 2, 2], [1, 0, 0]], [[2, 2, 2,...
#
#     average_percentage_correct  count_perfect_scores
# 0                          1.0                     4
# 1                          1.0                     4
# 2                          1.0                     4
# 3                          1.0                     4
# 4                          1.0                     4
# 5                          1.0                     4
# 7                          1.0                     4
# 8                          1.0                     4
# 9                          1.0                     4
# 10                         1.0                     4
# 11                         1.0                     4
# 12                         1.0                     4
# 13                         1.0                     4
# 14                         1.0                     4
# 15                         1.0                     4
# 16                         1.0                     4
# 17                         1.0                     4
# 18                         1.0                     4
# 19                         1.0                     4
# 21                         1.0                     4
# 22                         1.0                     4
# 24                         1.0                     4
